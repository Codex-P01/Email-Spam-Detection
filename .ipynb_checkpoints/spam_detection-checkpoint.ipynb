# %%
# !pip install nltk --quiet
# !pip install spacy --quiet
# !python -m spacy download en
# !pip install datasets --quiet

# %%
import spacy
import re
import pandas as pd
from datasets import load_from_disk

# %%
ds = load_from_disk("D:/read/Deep Learning/Mail Spam detection/train")
nlp = spacy.load("en_core_web_sm")

# %%
df = ds.to_pandas()
X = df[:]

# %%
X.head()
# Out:
#    message_id                                               text  label  \
# 0       33214  any software just for 15 $ - 99 $ understandin...      1
# 1       11929  perspective on ferc regulatory action client c...      0
# 2       19784  wanted to try ci 4 lis but thought it was way ...      1
# 3        2209  enron / hpl actuals for december 11 , 2000 tec...      0
# 4       15880  looking for cheap high - quality software ? ro...      1
#
#   label_text                                            subject  \
# 0       spam                  any software just for 15 $ - 99 $
# 1        ham  perspective on ferc regulatory action client c...
# 2       spam  wanted to try ci 4 lis but thought it was way ...
# 3        ham         enron / hpl actuals for december 11 , 2000
# 4       spam  looking for cheap high - quality software ? ro...
#
#                                              message       date
# 0  understanding oem software\nlead me not into t... 2005-06-18
# 1  19 th , 2 : 00 pm edt\nperspective on ferc reg... 2001-06-19
# 2  viagra at $ 1 . 12 per dose\nready to boost yo... 2004-09-11
# 3  teco tap 30 . 000 / enron ; 120 . 000 / hpl ga... 2000-12-12
# 4  water past also , burn , course . gave country... 2005-02-13

# %%
X.columns
# Out:
# Index(['message_id', 'text', 'label', 'label_text', 'subject', 'message',
#        'date'],
#       dtype='str')

# %%
X.isna().sum()
# Out:
# message_id    0
# text          0
# label         0
# label_text    0
# subject       0
# message       0
# date          0
# dtype: int64

# %%
X_train = X[['text', 'subject']]
y_train = X[['label']]

# %%
lang = spacy.blank('en')

# %%
text = """On 12th March 2025, Rahul Sharma met with Ananya Gupta at 10:30 AM in Kolkata 
to discuss a data science project worth ₹50000. Rahul shared his contact details, including 
his email rahul.sharma98@gmail.com and phone number +91-9876543210, while Ananya provided 
hers as ananya.gupta@company.org and +91 91234 56789. They also looped in their colleague 
Dr. Amit Verma, who joined remotely from Delhi and can be reached at amit.verma@research.in. 
During the meeting, they reviewed 3 datasets containing over 1,20,000 records and finalized a 
deadline of 30/04/2025. Later, Rahul sent 2 follow-up emails and attached 5 documents totaling 15 MB. 
The team agreed to meet again after 7 days to track progress and ensure at least 95% accuracy 
in their NLP model built using spaCy."""

# %%
tokens = lang(text)

# %%
for token in tokens:
    print(f"{token}--> {token.is_alpha}|{token.like_num}|{token.like_email}|{token.is_stop}|{token.is_space}")
# Out:
# On--> True|False|False|True|False
# 12th--> False|True|False|False|False
# March--> True|False|False|False|False
# 2025--> False|True|False|False|False
# ,--> False|False|False|False|False
# Rahul--> True|False|False|False|False
# Sharma--> True|False|False|False|False
# met--> True|False|False|False|False
# with--> True|False|False|True|False
# Ananya--> True|False|False|False|False
# Gupta--> True|False|False|False|False
# at--> True|False|False|True|False
# 10:30--> False|False|False|False|False
# AM--> True|False|False|True|False
# in--> True|False|False|True|False
# Kolkata--> True|False|False|False|False
#
# --> False|False|False|False|True
# to--> True|False|False|True|False
# discuss--> True|False|False|False|False
# a--> True|False|False|True|False
# data--> True|False|False|False|False
# science--> True|False|False|False|False
# project--> True|False|False|False|False
# worth--> True|False|False|False|False
# ₹--> False|False|False|False|False
# 50000--> False|True|False|False|False
# .--> False|False|False|False|False
# Rahul--> True|False|False|False|False
# shared--> True|False|False|False|False
# his--> True|False|False|True|False
# contact--> True|False|False|False|False
# details--> True|False|False|False|False
# ,--> False|False|False|False|False
# including--> True|False|False|False|False
#
# --> False|False|False|False|True
# his--> True|False|False|True|False
# email--> True|False|False|False|False
# rahul.sharma98@gmail.com--> False|False|True|False|False
# and--> True|False|False|True|False
# phone--> True|False|False|False|False
# number--> True|False|False|False|False
# +91--> False|True|False|False|False
# ---> False|False|False|False|False
# 9876543210--> False|True|False|False|False
# ,--> False|False|False|False|False
# while--> True|False|False|True|False
# Ananya--> True|False|False|False|False
# provided--> True|False|False|False|False
#
# --> False|False|False|False|True
# hers--> True|False|False|True|False
# as--> True|False|False|True|False
# ananya.gupta@company.org--> False|False|True|False|False
# and--> True|False|False|True|False
# +91--> False|True|False|False|False
# 91234--> False|True|False|False|False
# 56789--> False|True|False|False|False
# .--> False|False|False|False|False
# They--> True|False|False|True|False
# also--> True|False|False|True|False
# looped--> True|False|False|False|False
# in--> True|False|False|True|False
# their--> True|False|False|True|False
# colleague--> True|False|False|False|False
#
# --> False|False|False|False|True
# Dr.--> False|False|False|False|False
# Amit--> True|False|False|False|False
# Verma--> True|False|False|False|False
# ,--> False|False|False|False|False
# who--> True|False|False|True|False
# joined--> True|False|False|False|False
# remotely--> True|False|False|False|False
# from--> True|False|False|True|False
# Delhi--> True|False|False|False|False
# and--> True|False|False|True|False
# can--> True|False|False|True|False
# be--> True|False|False|True|False
# reached--> True|False|False|False|False
# at--> True|False|False|True|False
# amit.verma@research.in--> False|False|True|False|False
# .--> False|False|False|False|False
#
# --> False|False|False|False|True
# During--> True|False|False|True|False
# the--> True|False|False|True|False
# meeting--> True|False|False|False|False
# ,--> False|False|False|False|False
# they--> True|False|False|True|False
# reviewed--> True|False|False|False|False
# 3--> False|True|False|False|False
# datasets--> True|False|False|False|False
# containing--> True|False|False|False|False
# over--> True|False|False|True|False
# 1,20,000--> False|True|False|False|False
# records--> True|False|False|False|False
# and--> True|False|False|True|False
# finalized--> True|False|False|False|False
# a--> True|False|False|True|False
#
# --> False|False|False|False|True
# deadline--> True|False|False|False|False
# of--> True|False|False|True|False
# 30/04/2025--> False|False|False|False|False
# .--> False|False|False|False|False
# Later--> True|False|False|False|False
# ,--> False|False|False|False|False
# Rahul--> True|False|False|False|False
# sent--> True|False|False|False|False
# 2--> False|True|False|False|False
# follow--> True|False|False|False|False
# ---> False|False|False|False|False
# up--> True|False|False|True|False
# emails--> True|False|False|False|False
# and--> True|False|False|True|False
# attached--> True|False|False|False|False
# 5--> False|True|False|False|False
# documents--> True|False|False|False|False
# totaling--> True|False|False|False|False
# 15--> False|True|False|False|False
# MB--> True|False|False|False|False
# .--> False|False|False|False|False
#
# --> False|False|False|False|True
# The--> True|False|False|True|False
# team--> True|False|False|False|False
# agreed--> True|False|False|False|False
# to--> True|False|False|True|False
# meet--> True|False|False|False|False
# again--> True|False|False|True|False
# after--> True|False|False|True|False
# 7--> False|True|False|False|False
# days--> True|False|False|False|False
# to--> True|False|False|True|False
# track--> True|False|False|False|False
# progress--> True|False|False|False|False
# and--> True|False|False|True|False
# ensure--> True|False|False|False|False
# at--> True|False|False|True|False
# least--> True|False|False|True|False
# 95--> False|True|False|False|False
# %--> False|False|False|False|False
# accuracy--> True|False|False|False|False
#
# --> False|False|False|False|True
# in--> True|False|False|True|False
# their--> True|False|False|True|False
# NLP--> True|False|False|False|False
# model--> True|False|False|False|False
# built--> True|False|False|False|False
# using--> True|False|False|True|False
# spaCy--> True|False|False|False|False
# .--> False|False|False|False|False

# %%
nums = [n.text for n in tokens if n.like_num]
nums
# Out:
# ['12th',
#  '2025',
#  '50000',
#  '+91',
#  '9876543210',
#  '+91',
#  '91234',
#  '56789',
#  '3',
#  '1,20,000',
#  '2',
#  '5',
#  '15',
#  '7',
#  '95']

# %%
mails = [m.text for m in tokens if m.like_email]
mails
# Out:
# ['rahul.sharma98@gmail.com',
#  'ananya.gupta@company.org',
#  'amit.verma@research.in']

# %%
names = [n.text for n in tokens.ents if n.label_ == 'PERSON']
names
# Out:
# []
