# %%
# !pip install nltk --quiet
# !pip install spacy --quiet
# !python -m spacy download en
# !pip install datasets --quiet
# !pip install scikit-learn --quiet

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import spacy
import re
import pandas as pd
import joblib
from datasets import load_from_disk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
ds = load_from_disk("/content/drive/MyDrive/Projects Preparation/Mail Spam detection/train")
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner", "attribute_ruler"])

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'lemmatizer']

# %%
df = ds.to_pandas()
X = df[:]

# %%
X.head()
# Out:
#    message_id                                               text  label  \
# 0       33214  any software just for 15 $ - 99 $ understandin...      1
# 1       11929  perspective on ferc regulatory action client c...      0
# 2       19784  wanted to try ci 4 lis but thought it was way ...      1
# 3        2209  enron / hpl actuals for december 11 , 2000 tec...      0
# 4       15880  looking for cheap high - quality software ? ro...      1
#
#   label_text                                            subject  \
# 0       spam                  any software just for 15 $ - 99 $
# 1        ham  perspective on ferc regulatory action client c...
# 2       spam  wanted to try ci 4 lis but thought it was way ...
# 3        ham         enron / hpl actuals for december 11 , 2000
# 4       spam  looking for cheap high - quality software ? ro...
#
#                                              message       date
# 0  understanding oem software\nlead me not into t... 2005-06-18
# 1  19 th , 2 : 00 pm edt\nperspective on ferc reg... 2001-06-19
# 2  viagra at $ 1 . 12 per dose\nready to boost yo... 2004-09-11
# 3  teco tap 30 . 000 / enron ; 120 . 000 / hpl ga... 2000-12-12
# 4  water past also , burn , course . gave country... 2005-02-13

# %%
X.columns
# Out:
# Index(['message_id', 'text', 'label', 'label_text', 'subject', 'message',
#        'date'],
#       dtype='object')

# %%
X.isna().sum()
# Out:
# message_id    0
# text          0
# label         0
# label_text    0
# subject       0
# message       0
# date          0
# dtype: int64

# %%
X.shape
# Out:
# (31716, 7)

# %%
X, _= train_test_split(X, train_size=0.4, stratify=X['label'], random_state=42)

# %%
X.shape
# Out:
# (12686, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X['message'], X['label'], test_size=0.3, stratify=X['label'], random_state=42)

# %%
print(f"{X_train.shape}|{X_test.shape}")
# Out:
# (8880,)|(3806,)

# %% [markdown]
# ##Preprocessing

# %%
def cleaning(doc):
  return [token.lemma_ for token in doc
          if token.is_alpha and
          len(token.text) > 2]

# %% [markdown]
# ###Training Sample Preprocessing

# %%
X_train = X_train.to_frame()

# %%
X_train['message'] = X_train['message'].str.lower()

# %%
docs = []
docs = list(nlp.pipe(X_train['message']))
# Out:
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/lemmatizer.py:187: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
X_train['tokens'] = [cleaning(doc) for doc in docs]
X_train.head()
# Out:
#                                                  message  \
# 9899   hallo ! be good , be kind , be humane , and ch...
# 9179   louise ,\ni understand there is concern that t...
# 27241  listed in domino directory\nyour message\nsubj...
# 31365  my only concern is that john ( i am told ) spo...
# 9429   to :\nandres almazan\ndon chew\njohn freeman\n...
#
#                                                   tokens
# 9899   [hallo, good, kind, humane, and, charitable, l...
# 9179   [louise, understand, there, concern, that, the...
# 27241  [listed, domino, directory, your, message, sub...
# 31365  [only, concern, that, john, told, spoke, gas, ...
# 9429   [andres, almazan, don, chew, john, freeman, ge...

# %%
X_train['clean_text'] = X_train['tokens'].apply(lambda x: " ".join(x))
X_train.head()
# Out:
#                                                  message  \
# 9899   hallo ! be good , be kind , be humane , and ch...
# 9179   louise ,\ni understand there is concern that t...
# 27241  listed in domino directory\nyour message\nsubj...
# 31365  my only concern is that john ( i am told ) spo...
# 9429   to :\nandres almazan\ndon chew\njohn freeman\n...
#
#                                                   tokens  \
# 9899   [hallo, good, kind, humane, and, charitable, l...
# 9179   [louise, understand, there, concern, that, the...
# 27241  [listed, domino, directory, your, message, sub...
# 31365  [only, concern, that, john, told, spoke, gas, ...
# 9429   [andres, almazan, don, chew, john, freeman, ge...
#
#                                               clean_text
# 9899   hallo good kind humane and charitable love you...
# 9179   louise understand there concern that the value...
# 27241  listed domino directory your message subject s...
# 31365  only concern that john told spoke gas and powe...
# 9429   andres almazan don chew john freeman geoge gau...

# %%
cv = CountVectorizer(ngram_range=(1,3))
X_train_cv = cv.fit_transform(X_train['clean_text'].values)

# %%
X_train_arr = X_train_cv.toarray()

# %% [markdown]
# ###Test Sample Preprocessing

# %%
X_test = X_test.to_frame()

# %%
X_test['message'] = X_test['message'].str.lower()

# %%
test_docs = []
test_docs = list(nlp.pipe(X_test['message']))
# Out:
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/lemmatizer.py:187: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
X_test['tokens'] = [cleaning(doc) for doc in test_docs]
X_test.head()
# Out:
#                                                  message  \
# 28384  pls review the executive list file on n : \ ho...
# 26807  in 1891 a collect call alyssa milano in 1824 s...
# 4050   band ago , made suffix . close ask believe . g...
# 26670  important instructions for sending in expense ...
# 6715   note : if this eamil is not fit for you , plea...
#
#                                                   tokens
# 28384  [pls, review, the, executive, list, file, home...
# 26807  [collect, call, alyssa, milano, small, world, ...
# 4050   [band, ago, made, suffix, close, ask, believe,...
# 26670  [important, instructions, for, sending, expens...
# 6715   [note, this, eamil, not, fit, for, you, please...

# %%
X_test['clean_text'] = X_test['tokens'].apply(lambda x: " ".join(x))
X_test.head()
# Out:
#                                                  message  \
# 28384  pls review the executive list file on n : \ ho...
# 26807  in 1891 a collect call alyssa milano in 1824 s...
# 4050   band ago , made suffix . close ask believe . g...
# 26670  important instructions for sending in expense ...
# 6715   note : if this eamil is not fit for you , plea...
#
#                                                   tokens  \
# 28384  [pls, review, the, executive, list, file, home...
# 26807  [collect, call, alyssa, milano, small, world, ...
# 4050   [band, ago, made, suffix, close, ask, believe,...
# 26670  [important, instructions, for, sending, expens...
# 6715   [note, this, eamil, not, fit, for, you, please...
#
#                                               clean_text
# 28384  pls review the executive list file homedept nn...
# 26807       collect call alyssa milano small world songs
# 4050   band ago made suffix close ask believe game go...
# 26670  important instructions for sending expense rep...
# 6715   note this eamil not fit for you please reply w...

# %%
X_test_cv = cv.transform(X_test['clean_text'].values)

# %%
X_test_arr = X_test_cv.toarray()

# %%
X_test_arr[:1]

# %% [markdown]
# ##Model Creation and Traning

# %%
model = MultinomialNB()

# %%
history = model.fit(X_train_arr, y_train)

# %% [markdown]
# ##Saving Model

# %%
joblib.dump(model, "/content/drive/MyDrive/Projects Preparation/Mail Spam detection/spam_detection.pkl")

# %% [markdown]
# ##Loading Model

# %%
model = joblib.load("/content/drive/MyDrive/Projects Preparation/Mail Spam detection/spam_detection.pkl")

# %% [markdown]
# ##Prediction and Evaluation

# %%
y_pre = model.predict(X_test_arr)

# %%
print(classification_report(y_test, y_pre))

# %%
texts = [
    '''We noticed you haven’t been opening our emails, and we don’t want to clutter your inbox.



If you still want updates, no action needed, you’ll continue receiving our emails.



If this email isn’t opened in 3 days, we’ll automatically unsubscribe you from our list. No worries, you can re-subscribe anytime here.'''
]

# %%
tokens = []
tokens = list(nlp.pipe(texts))

# %%
clean_token = [cleaning(token) for token in tokens]
clean_token

# %%
clean_text = [" ".join(tokens) for tokens in clean_token]
clean_text

# %%
texts_count = cv.transform(clean_text)
predictions = model.predict(texts_count)

# %%
labels = ["Spam" if pred == 1 else "Ham" for pred in predictions]
print(labels)
